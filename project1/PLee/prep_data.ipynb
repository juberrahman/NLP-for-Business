# %% [markdown]
# ### Data Preparation for Game Reviews Data
#
# In this notebook, we prepare the data which we have scraped from the games review website of Common Sense Media.  Data preparation consists of:
# - removing rows without labels
# - removing rows that are marked to be deleted (indicated in column 'remove')
# - concatenating review titles and reviews proper to form a single column for review content
#
# The final dataframe consists of 606 rows, and retains only 2 columns: 'review' and 'label'.  This dataframe is output as a csv file.

# %%
import pandas as pd

# %%
# read in the raw scraped data
df = pd.read_csv("data/run_results13.csv")
df
# Out:
#         cont_button_rev_links_selection2_name  \
# 0                              It’s too scary
# 1                       A GOOD RACING GAME!!!
# 2                                 Great game!
# 3               Son loves it, but too violent
# 4                                  Nostalgia.
# ..                                        ...
# 693  Best bottle Royale game I've ever played
# 694                 Let your kids play this .
# 695                  delete fortnite get this
# 696                              Really Good!
# 697                                It’s great
#
#            cont_button_rev_links_selection2_selection3 label remove
# 0    It's funny but the Car never has any clothes o...     a    NaN
# 1    Although the movie is not that good, the game ...     s    NaN
# 2    I think this game is great! My husband, son, a...     s    NaN
# 3    I am disappointed that there are guns and shoo...     a    NaN
# 4    has quite a few explosions (not that bad) and ...     s    NaN
# ..                                                 ...   ...    ...
# 693  Well this game does have a little bit of blood...   NaN    NaN
# 694  If you are a parent and think that your 10 yea...   NaN    NaN
# 695  this game is very fun. you take away the blood...   NaN    NaN
# 696  Its really good and not gory at all. I think i...   NaN    NaN
# 697  I think that it’s fine for other kids since it...   NaN    NaN
#
# [698 rows x 4 columns]

# %%
# get the counts of the different non-null label values
df['label'].value_counts()
# Out:
# s    427
# a    187
# Name: label, dtype: int64

# %%
# filter out rows without labels (i.e. NaN)
df_labels = df[ df['label'].isnull() == False ]
df_labels
# Out:
#                  cont_button_rev_links_selection2_name  \
# 0                                       It’s too scary
# 1                                A GOOD RACING GAME!!!
# 2                                          Great game!
# 3                        Son loves it, but too violent
# 4                                           Nostalgia.
# ..                                                 ...
# 614                                             Listen
# 615  An epic game that can be for anyone just needs...
# 616                                       Amazing game
# 617  Probably the worst in the franchise but fine f...
# 618                               Same game every year
#
#            cont_button_rev_links_selection2_selection3 label remove
# 0    It's funny but the Car never has any clothes o...     a    NaN
# 1    Although the movie is not that good, the game ...     s    NaN
# 2    I think this game is great! My husband, son, a...     s    NaN
# 3    I am disappointed that there are guns and shoo...     a    NaN
# 4    has quite a few explosions (not that bad) and ...     s    NaN
# ..                                                 ...   ...    ...
# 614  This game is one I am sure a lot of parents ar...     a    NaN
# 615  I bought this game recently even tho the more ...     s    NaN
# 616  My son wanted the game, At first I wasnt havin...     s    NaN
# 617                                                NaN     s    NaN
# 618  I am a professional PEGI reviewer and rate gam...     s    NaN
#
# [614 rows x 4 columns]

# %%
# remove rows with 'remove' column is not NaN
df_labels['remove'].value_counts()
# Out:
# delete     7
# delete?    1
# Name: remove, dtype: int64

# %%
df_clean = df_labels[ df_labels['remove'].isnull() == True ]
df_clean
# Out:
#                  cont_button_rev_links_selection2_name  \
# 0                                       It’s too scary
# 1                                A GOOD RACING GAME!!!
# 2                                          Great game!
# 3                        Son loves it, but too violent
# 4                                           Nostalgia.
# ..                                                 ...
# 614                                             Listen
# 615  An epic game that can be for anyone just needs...
# 616                                       Amazing game
# 617  Probably the worst in the franchise but fine f...
# 618                               Same game every year
#
#            cont_button_rev_links_selection2_selection3 label remove
# 0    It's funny but the Car never has any clothes o...     a    NaN
# 1    Although the movie is not that good, the game ...     s    NaN
# 2    I think this game is great! My husband, son, a...     s    NaN
# 3    I am disappointed that there are guns and shoo...     a    NaN
# 4    has quite a few explosions (not that bad) and ...     s    NaN
# ..                                                 ...   ...    ...
# 614  This game is one I am sure a lot of parents ar...     a    NaN
# 615  I bought this game recently even tho the more ...     s    NaN
# 616  My son wanted the game, At first I wasnt havin...     s    NaN
# 617                                                NaN     s    NaN
# 618  I am a professional PEGI reviewer and rate gam...     s    NaN
#
# [606 rows x 4 columns]

# %%
# drop the 'remove' column
df_clean.drop(['remove'], axis=1, inplace=True)
# Out:
# /var/folders/q6/4vk5yrts387cp_3qs430rhqc0000gn/T/ipykernel_5326/3150991030.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.drop(['remove'], axis=1, inplace=True)

# %%
# check the counts of the label values
df_clean['label'].value_counts()
# Out:
# s    420
# a    186
# Name: label, dtype: int64

# %%
# a function to replace the NaNs in 'review' column with empty str
def replace_nan( val ):
    if type(val) == str:
        return val
    else:
        return ""

# %%
# rename the columns
df_clean.columns = ['title', 'review', 'label']
df_clean
# Out:
#                                                  title  \
# 0                                       It’s too scary
# 1                                A GOOD RACING GAME!!!
# 2                                          Great game!
# 3                        Son loves it, but too violent
# 4                                           Nostalgia.
# ..                                                 ...
# 614                                             Listen
# 615  An epic game that can be for anyone just needs...
# 616                                       Amazing game
# 617  Probably the worst in the franchise but fine f...
# 618                               Same game every year
#
#                                                 review label
# 0    It's funny but the Car never has any clothes o...     a
# 1    Although the movie is not that good, the game ...     s
# 2    I think this game is great! My husband, son, a...     s
# 3    I am disappointed that there are guns and shoo...     a
# 4    has quite a few explosions (not that bad) and ...     s
# ..                                                 ...   ...
# 614  This game is one I am sure a lot of parents ar...     a
# 615  I bought this game recently even tho the more ...     s
# 616  My son wanted the game, At first I wasnt havin...     s
# 617                                                NaN     s
# 618  I am a professional PEGI reviewer and rate gam...     s
#
# [606 rows x 3 columns]

# %%
# replace all NaNs in the 'review' column with empty string
df_clean['review'] = df_clean['review'].apply( replace_nan )
# Out:
# /var/folders/q6/4vk5yrts387cp_3qs430rhqc0000gn/T/ipykernel_5326/2565415300.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['review'] = df_clean['review'].apply( replace_nan )

# %%
df_clean
# Out:
#                                                  title  \
# 0                                       It’s too scary
# 1                                A GOOD RACING GAME!!!
# 2                                          Great game!
# 3                        Son loves it, but too violent
# 4                                           Nostalgia.
# ..                                                 ...
# 614                                             Listen
# 615  An epic game that can be for anyone just needs...
# 616                                       Amazing game
# 617  Probably the worst in the franchise but fine f...
# 618                               Same game every year
#
#                                                 review label
# 0    It's funny but the Car never has any clothes o...     a
# 1    Although the movie is not that good, the game ...     s
# 2    I think this game is great! My husband, son, a...     s
# 3    I am disappointed that there are guns and shoo...     a
# 4    has quite a few explosions (not that bad) and ...     s
# ..                                                 ...   ...
# 614  This game is one I am sure a lot of parents ar...     a
# 615  I bought this game recently even tho the more ...     s
# 616  My son wanted the game, At first I wasnt havin...     s
# 617                                                        s
# 618  I am a professional PEGI reviewer and rate gam...     s
#
# [606 rows x 3 columns]

# %%
# create a new column that contains the review title appended with the review proper
df_clean['title_review'] = df_clean['title'] + " " + df_clean['review']
# Out:
# /var/folders/q6/4vk5yrts387cp_3qs430rhqc0000gn/T/ipykernel_5326/1644740417.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['title_review'] = df_clean['title'] + " " + df_clean['review']

# %%
df_clean
# Out:
#                                                  title  \
# 0                                       It’s too scary
# 1                                A GOOD RACING GAME!!!
# 2                                          Great game!
# 3                        Son loves it, but too violent
# 4                                           Nostalgia.
# ..                                                 ...
# 614                                             Listen
# 615  An epic game that can be for anyone just needs...
# 616                                       Amazing game
# 617  Probably the worst in the franchise but fine f...
# 618                               Same game every year
#
#                                                 review label  \
# 0    It's funny but the Car never has any clothes o...     a
# 1    Although the movie is not that good, the game ...     s
# 2    I think this game is great! My husband, son, a...     s
# 3    I am disappointed that there are guns and shoo...     a
# 4    has quite a few explosions (not that bad) and ...     s
# ..                                                 ...   ...
# 614  This game is one I am sure a lot of parents ar...     a
# 615  I bought this game recently even tho the more ...     s
# 616  My son wanted the game, At first I wasnt havin...     s
# 617                                                        s
# 618  I am a professional PEGI reviewer and rate gam...     s
#
#                                           title_review
# 0    It’s too scary It's funny but the Car never ha...
# 1    A GOOD RACING GAME!!! Although the movie is no...
# 2    Great game! I think this game is great! My hus...
# 3    Son loves it, but too violent I am disappointe...
# 4    Nostalgia. has quite a few explosions (not tha...
# ..                                                 ...
# 614  Listen This game is one I am sure a lot of par...
# 615  An epic game that can be for anyone just needs...
# 616  Amazing game My son wanted the game, At first ...
# 617  Probably the worst in the franchise but fine f...
# 618  Same game every year I am a professional PEGI ...
#
# [606 rows x 4 columns]

# %%
# check that the new 'title_review' column does not have any null values
any( df_clean['title_review'].isnull() )
# Out:
# False

# %%
# drop 'title' and 'review' columns
df_clean.drop( ['title', 'review'], axis=1, inplace=True )
# Out:
# /var/folders/q6/4vk5yrts387cp_3qs430rhqc0000gn/T/ipykernel_5326/3405605708.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.drop( ['title', 'review'], axis=1, inplace=True )

# %%
# check for any null values in the dataframe
any( df_clean['title_review'].isnull() )
# Out:
# False

# %%
any( df_clean['label'].isnull())
# Out:
# False

# %%
df_clean.isnull().any()
# Out:
# label           False
# title_review    False
# dtype: bool

# %%
# do a final look through, before writing data out to file
df_clean
# Out:
#     label                                       title_review
# 0       a  It’s too scary It's funny but the Car never ha...
# 1       s  A GOOD RACING GAME!!! Although the movie is no...
# 2       s  Great game! I think this game is great! My hus...
# 3       a  Son loves it, but too violent I am disappointe...
# 4       s  Nostalgia. has quite a few explosions (not tha...
# ..    ...                                                ...
# 614     a  Listen This game is one I am sure a lot of par...
# 615     s  An epic game that can be for anyone just needs...
# 616     s  Amazing game My son wanted the game, At first ...
# 617     s  Probably the worst in the franchise but fine f...
# 618     s  Same game every year I am a professional PEGI ...
#
# [606 rows x 2 columns]

# %%
# write the cleaned dataframe to a csv file
df_clean.to_csv("data/labelled_reviews.csv", index=False)
