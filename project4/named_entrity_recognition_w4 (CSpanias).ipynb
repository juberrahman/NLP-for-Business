# %% [markdown]
# # Name Entity Recognition
# by [CSpanias](https://cspanias.github.io/aboutme/), 4th Week's Project for [Solving Business Problems with NLP](https://omdena.com/course/solving-business-problems-with-nlp/) by Omdena, 03/2022

# %% [markdown]
# # CONTENT
# 1. [Import Data](#data)
# 1. [Named Entity Recognition with spaCy](#ner)

# %% [markdown]
# This project's goal is to __identify the named entities__ in the documents and answer the following questions:
# - Name of parties involved in the contract
# - Place of the contract
# - Date of contract & Contact Duration
# - Contract value (Amount of money )
#
# We also need to structure the information extracted in a __tabular format__.

# %% [markdown]
# <a name='docs'></a>
# # 1. Import Data

# %% [markdown]
# First we have to import data in a suitable form. For now we have __510__ `.txt` files.
#
# Our goal is to make a list where each element represents the contents of each file.

# %%
import os

# folder path
path = r"C:\Users\10inm\nlp_resources\nlp_omdena\w4\legal_contract_txt"

# change directory
os.chdir(path)

# create empty list
docs = []
# iterate through all files
for file in os.listdir():
    # check whether file is in text format or not
    if file.endswith(".txt"):
        file_path = f"{path}\{file}"
        with open(file_path, encoding="UTF-8") as f:
            docs.append(f.read())

# %%
print(f"The list `docs` contains {len(docs)} elements. The first 100 characters of the 1st element is:\n\n{docs[0][:100]}")
# Out:
# The list `docs` contains 510 elements. The first 100 characters of the 1st element is:
#
# CO-BRANDING AND ADVERTISING AGREEMENT
#
# THIS CO-BRANDING AND ADVERTISING AGREEMENT (the "Agreement")

# %% [markdown]
# <a name='ner'></a>
# # 2. Named Entity Recognition with `spaCy`

# %% [markdown]
# More info on NER with spaCy [here](https://spacy.io/usage/linguistic-features#named-entities).

# %%
import spacy

def tabular_ner(file, tag=None):
    
    # load spacy pipeline
    nlp = spacy.load("en_core_web_sm")
    # apply pipeline to file
    doc = nlp(file)
    
    # iterate through named entities
    for ent in doc.ents:
        # extract desired characteristics
        text = [ent.text for ent in doc.ents]
        labels = [ent.label_ for ent in doc.ents]
        
        # convert NER to tabular format
        df = pd.DataFrame(list(zip(text, labels)), columns=['Text', 'Label'])
    # if no specific tag is provided
    if tag == None:
        # return whole dataframe
        return df
    # if a tag is provided
    else: # tag != None
        # return the named entities with that tag
        return df[(df['Label'] == tag)]

# %%
# return all NER
tabular_ner(docs[0])
# Out:
#                                       Text     Label
# 0    CO-BRANDING AND ADVERTISING AGREEMENT       ORG
# 1                            June 21, 1999      DATE
# 2                      the "Effective Date       LAW
# 3                                     INC.       GPE
# 4                         S. Amphlett Blvd    PERSON
# ..                                     ...       ...
# 311                                      6  CARDINAL
# 312                                      7  CARDINAL
# 313                       2THEMART COM INC       ORG
# 314                                  10-12  CARDINAL
# 315                              8/26/1999      DATE
#
# [316 rows x 2 columns]

# %%
# find the persons involved in a document
tabular_ner(docs[0], tag='PERSON').head()
# Out:
#                   Text   Label
# 4     S. Amphlett Blvd  PERSON
# 5            Suite 233  PERSON
# 8                94402  PERSON
# 10   Von Karman Avenue  PERSON
# 157             Trojan  PERSON

# %%
# find organizations included in doc
tabular_ner(docs[0], tag='ORG').head()
# Out:
#                                      Text Label
# 0   CO-BRANDING AND ADVERTISING AGREEMENT   ORG
# 17                            DEFINITIONS   ORG
# 19                        CO-BRANDED SITE   ORG
# 20                            Domain Name   ORG
# 22                        Co-Branded Site   ORG

# %%
# find dates included in doc
tabular_ner(docs[0], tag='DATE').head()
# Out:
#              Text Label
# 1   June 21, 1999  DATE
# 9           18301  DATE
# 15          92612  DATE
# 41      8/26/1999  DATE
# 52       2 months  DATE

# %%
# find places included in doc
tabular_ner(docs[0], tag='GPE').head()
# Out:
#           Text Label
# 3         INC.   GPE
# 6    San Mateo   GPE
# 7   California   GPE
# 12       Floor   GPE
# 13      Irvine   GPE

# %%
# find money sums included in doc
tabular_ner(docs[0], tag='MONEY').head()
# Out:
#                Text  Label
# 21   2TheMart Marks  MONEY
# 132  2TheMart Marks  MONEY
# 273             215  MONEY

# %% [markdown]
# We can also __visualize NER__ using `displacy`.

# %%
from spacy import displacy

# visualise entities

sentence_spans = list(doc.sents)

displacy.render(sentence_spans, style="ent", jupyter=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\spacy\displacy\__init__.py:200: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CO-BRANDING AND ADVERTISING AGREEMENT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br>THIS CO-BRANDING AND ADVERTISING AGREEMENT (the &quot;Agreement&quot;) is made as of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 21, 1999
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the &quot;Effective Date
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# &quot;) by and between I-ESCROW,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     INC.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , with its principal place of business at 1730
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S. Amphlett Blvd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Suite 233
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     San Mateo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     California
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     94402
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (&quot;i-Escrow&quot;), and 2THEMART.COM, INC. having its principal place of business at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     18301
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Von Karman Avenue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Floor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Irvine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     California
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     92612
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (&quot;2TheMart&quot;).</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"></br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DEFINITIONS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"></br></br>(a) &quot;CONTENT&quot; means all content or information, in any medium, provided by a party to the other party for use in conjunction with the performance of its obligations hereunder, including without limitation any text, music, sound, photographs, video, graphics, data or software. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Content provided by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2TheMart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  is referred to herein as &quot;2TheMart Content&quot; and Content provided by i-Escrow is referred to herein as &quot;i-Escrow Content.&quot;</br></br>(b) &quot;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CO-BRANDED SITE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# &quot; means the web-site accessible through
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Domain Name
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , for the Services implemented by i-Escrow. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The homepage of this web-site will visibly display both
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2TheMart Marks
#     <span style="font-size: 0.
